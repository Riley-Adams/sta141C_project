# %%
# import modules
import numpy as np
import pandas as pd

# %%
# read in data
gibbs_samples = pd.read_csv('gibbs_samples.csv', index_col=0)
gibbs_samples_all = pd.read_csv('gibbs_samples_all.csv', index_col=0)

# %%
gibbs_samples_all.plot(title="Gibbs Samples for Small Model (Including Burn-In)")

# %%
gibbs_samples.plot(title="Gibbs Samples for Small Model (Excluding Burn-In)")
